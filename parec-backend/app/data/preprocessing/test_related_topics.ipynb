# %%
from top2vec import Top2Vec
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load the saved model
model = Top2Vec.load('t2v_large')

# %%
# Define the input string
input_str = 'artificial intelligence'

print("Numbers of topics found by Top2Vec: ", model.get_num_topics())

topics_words, _, _ = model.get_topics()
print("Topics ordered by size: ", topics_words)
# Out:
# Numbers of topics found by Top2Vec:  215
# Topics ordered by size:  [['perform extensive' 'extensive experiments' 'supervised manner' ...
#   'approach outperforms' 'code https' 'effectiveness efficiency']
#  ['vertices' 'factor graphs' 'whose vertices' ... 'edges'
#   'maximum minimum' 'constant dimension']
#  ['invited' 'proceedings th' 'proceedings workshop' ... 'conferences'
#   'place th' 'formal']
#  ...
#  ['dct' 'transform dct' 'dct coefficients' ... 'ratio sir' 'power ratio'
#   'watermarking']
#  ['motifs' 'motif' 'motif finding' ... 'radiology reports'
#   'sparse coding' 'english german']
#  ['petri' 'petri nets' 'nets' ... 'special needs' 'article presents'
#   'complex hilbert']]

# %%
model.generate_topic_wordcloud(3, background_color='black', reduced=False)

# %%
print("Top words per topic: ", model.topic_words[1])
# Out:
# Top words per topic:  ['vertices' 'factor graphs' 'whose vertices' 'vertex' 'prove every'
#  'every vertex' 'number vertices' 'set vertices' 'vertices edges'
#  'vertices graph' 'give polynomial' 'known np' 'maximum number'
#  'polynomial size' 'free graphs' 'factor graph' 'connected vertex'
#  'graphs' 'maximum degree' 'finding maximum' 'vertex set' 'planar'
#  'expander graphs' 'treewidth' 'hard approximate' 'cubic graphs'
#  'known plaintext' 'chordal graphs' 'graphs bounded' 'bounded constant'
#  'vertex leafage' 'constant factor' 'cayley graphs' 'give simple'
#  'number edges' 'exact approximate' 'maximum correntropy' 'np complete'
#  'known upper' 'well known' 'fixed size' 'maximum posteriori'
#  'subset vertices' 'upper bounded' 'approximation factor'
#  'factor approximation' 'triangle' 'edges' 'maximum minimum'
#  'constant dimension']

# %%
topics_based_on_query, _, _, _ = model.query_topics(input_str, num_topics=1, reduced=False, tokenizer=None)
print("Words closest to input: ", topics_based_on_query)
# Out:
# Words closest to input:  [array(['ethical', 'ethics', 'ethical ai', 'ai', 'ethical issues',
#        'ai ethics', 'tech ethics', 'principles', 'governance',
#        'design principles', 'responsible ai', 'intelligence ai',
#        'society', 'regulation', 'conclude discussion',
#        'unstructured text', 'particularly important', 'engagement',
#        'transparency', 'discussion forums', 'broader', 'ai governance',
#        'particularly useful', 'stakeholders', 'legal',
#        'encouraging results', 'unstructured environments',
#        'discuss implications', 'intelligence', 'substantial improvements',
#        'important implications', 'diacritic restoration', 'perspectives',
#        'regulatory', 'academia', 'article discuss', 'article focuses',
#        'ai ml', 'detailed discussion', 'making decisions',
#        'thus facilitating', 'culture', 'become essential', 'human bodies',
#        'useful insights', 'broader range', 'essential role',
#        'image restoration', 'lives', 'article presents'], dtype='<U29')]

# %%
topic_words, word_scores, topic_scores, topic_nums = model.query_topics("machine learning", num_topics=5)

# %%
print(topic_words[0])
# Out:
# ['fairness' 'demographic' 'fairness aware' 'race' 'fair comparison'
#  'gender' 'demographic groups' 'fair' 'demographic characteristics'
#  'fairness avoid' 'fairness criteria' 'discrimination' 'biases'
#  'gender bias' 'proportional fairness' 'bias' 'selection bias'
#  'socio demographic' 'abelian groups' 'fair play' 'avoid bias'
#  'gender biases' 'sensitive attributes' 'age groups' 'protected'
#  'survey conducted' 'making decisions' 'motivated us' 'may arise'
#  'motivated recent' 'socio' 'extractive summarization' 'vary greatly'
#  'abstractive summarization' 'step towards' 'recent literature'
#  'important step' 'ethical' 'may affect' 'essential step' 'gender age'
#  'gender differences' 'across diverse' 'popularity bias' 'would like'
#  'secrecy fairness' 'make decisions' 'age gender' 'rather relying'
#  'mitigate risks']

# %%
# generate the topic wordcloud
topic_words, word_scores, topic_scores, topic_nums = model.search_topics(keywords=["reinforcement learning"], num_topics=1)
for topic in topic_nums:
    model.generate_topic_wordcloud(topic)
